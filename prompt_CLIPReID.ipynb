# %% [markdown]
# <a href="https://colab.research.google.com/github/narizzang/Animal-ReID/blob/main/prompt_CLIPReID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from PIL import Image
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os
import skimage
import IPython.display
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/new/CLIP-ReID")

# %%
# !git clone https://github.com/Syliz517/CLIP-ReID.git
# Out:
# Cloning into 'CLIP-ReID'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 99 (delta 30), reused 54 (delta 18), pack-reused 1 (from 1)
# Receiving objects: 100% (99/99), 4.30 MiB | 7.89 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !pip install yacs
# !pip install timm
# !pip install scikit-image
# !pip install tqdm
# !pip install ftfy
# !pip install regex
# !pip install torchvision
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python train_clipreid.py --config_file configs/person/cnn_clipreid.yml
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2024-11-26 11:55:31,534 transreid INFO: Saving model in the path :/content/drive/MyDrive/output/person/market1501/0003
# 2024-11-26 11:55:31,535 transreid INFO: Namespace(config_file='configs/person/cnn_clipreid.yml', opts=[], local_rank=0)
# 2024-11-26 11:55:31,535 transreid INFO: Loaded configuration file configs/person/cnn_clipreid.yml
# 2024-11-26 11:55:31,537 transreid INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'RN50'
#   ID_LOSS_WEIGHT : 1.0
#   TRIPLET_LOSS_WEIGHT : 1.0
#   I2T_LOSS_WEIGHT : 1.0
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
# ...
